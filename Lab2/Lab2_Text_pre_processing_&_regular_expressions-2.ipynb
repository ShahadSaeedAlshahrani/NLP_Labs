# %% [markdown]
# # Lab2: Text Pre-processing and Regular Expressions

# %% [markdown]
#  In this lab, you will learn essential techniques for preparing and cleaning text data using various pre-processing steps. Additionally, you will gain hands-on experience with regular expressions, a powerful tool for pattern matching and text manipulation in natural language processing (NLP) tasks.

# %% [markdown]
# _____________________________________________________________________________________________

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# Regular expressions (regex) extremely useful in extracting information from any text by searching for one or more matches of a specific search pattern
#
# https://www.regexpal.com/

# %% [markdown]
# #### Regular Expressions use cases
#
# - Data pre-processing
# - Pattern matching
# - Text feature Engineering
# - Web scraping
# - Data validation
# - Data extraction
#
# An example use case is extracting all hashtags from a tweet, or getting email addresses or phone numbers from large unstructured text content.

# %% [markdown]
# ## Regular Expressions with Python
#
# Python provides a convenient built-in module for managing regular expressions:
#
# > import re
#
# We can import it as we import any other Python library.

# %% [markdown]
# ### Important symbols in Regular Expression (For your reference)
#
# Let’s start with the basic regular expression characters and some examples:
#
# - (^) : Matches the expression to its right, at the start of a string before it finds a line break.
# - ($) : Matches the expression to its left, at the end of a string before it finds a line break.
# - (.) : Matches any character except newline.
# - (a) : Matches exactly one character.
# - (ab) : Matches the string ab.
#
# ----------------------------------------------------------------------------
# Quantifiers:
#
# - (a|b) : Matches expression a or b. If a is matched first, b is not checked;
# - (+) : Matches the expression to its left 1 or more times;
# - (*) : Matches the expression to its left 0 or more times;
# - (?) : Matches the expression to its left 0 or 1 times.
# ----------------------------------------------------------------------------
# Character Classes:
#
# - \w : Matches alphanumeric characters, that is a-z, A-Z, 0–9, and underscore(_);
# - \W : Matches non-alphanumeric characters, that is except a-z, A-Z, 0–9, and _;
# - \d : Matches digits, from 0–9;
# - \D : Matches any non-digits;
# - \s : Matches whitespace characters, which also include the \t, \n, \r, and space characters;
# - \S : Matches non-whitespace characters.
# - \n : Matches a newline character;
# - \t : Matches a tab character;
# - \b : Matches the word boundary (or empty string) at the start and end of a word;
# - \B : Matches where \b does not, that is non-word boundary.
#
# ----------------------------------------------------------------------------
# Sets:
#
# - [abc] : Matches either a, b, or c. It does not match abc;
# - [a-z] : Matches any alphabet from a to z;
# - [A-Z] : Matches any alphabets in capital from A to Z;
# - [a\-p] : Matches a, -, or p. It matches - because \ escapes it;
# - [-z] : Matches - or z;
# - [a-z0–9] : Matches characters from a to z or from 0 to 9.
# - [(+*)] : Special characters become literal inside a set, so this matches (, +, *, or );
# - [^ab5] : Adding ^ excludes any character in the set. Here, it matches characters that are not a, b, or 5;
# ----------------------------------------------------------------------------
#
#
# ### Regular Expression functions

# %% [markdown]
# #### search
#
# Search for pattern occurrences in a string using the search function of the **re module**. This function returns a match object, containing the first matched substring (or None, if it doesn’t exist) and its position inside the original string.

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search("I", text)) #r"I" means it's a raw string literal
print(re.search("se.$", text)) #$ Search at the end of the string
print(re.search("am", text))
print(re.search("m", text))
print(re.search("AI", text))
# Out:
# <re.Match object; span=(0, 1), match='I'>
# <re.Match object; span=(26, 29), match='se.'>
# <re.Match object; span=(2, 4), match='am'>
# <re.Match object; span=(3, 4), match='m'>
# None

# %% [markdown]
# #### match
#
# The match function is similar to search, but it only tries to match the pattern at the beginning of the target string.

# %%
import re
re.match?
# Out:
# Signature: re.match(pattern, string, flags=0)
# Docstring:
# Try to apply the pattern at the start of the string, returning
# a Match object, or None if no match was found.
# File:      c:\users\shaha\appdata\local\python\pythoncore-3.14-64\lib\re\__init__.py
# Type:      function

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search("I.*", text)) #global
print(re.match("I.*", text)) #local >> search at the start of the string

print(re.search("enjoying.*", text))
print(re.match("enjoying.*", text))
# Out:
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(5, 29), match='enjoying the NLP course.'>
# None

# %%
import re

text = '1999 was the year I was born.'

print(re.search(r"[a-zA-Z]+", text))
print(re.match(r"[a-zA-Z]+", text))
# Out:
# <re.Match object; span=(5, 8), match='was'>
# None

# %% [markdown]
# Search does a global search, whereas match does a local search!
#
# **Match** is often used when you need to check if the string starts with a specific pattern.
#
#
# **Search** is used when you want to find a pattern anywhere within the string.

# %% [markdown]
# #### findall
#
# The findall function looks for all the pattern matches in the target string (whereas search and match look only for the first occurrence).
#
# - `re.findall()` returns a list of all matches.
#
# - `re.finditer()` returns an iterator of match objects.
#
# - `re.search() and re.match()` both return a single match object for the first occurrence (but differ in where they start matching: match() matches only at the start of the string, search() anywhere).

# %%
import re

text1 = "a 1 b 2 c 3"
text2 = "a1 b2 c 3"
text3 = "a 1 b 222 c 3"

print(re.findall(r"\d+", text1)) #match any digit
print(re.findall(r"\d+", text2))
print(re.findall(r"\d+", text3))
# Out:
# ['1', '2', '3']
# ['1', '2', '3']
# ['1', '222', '3']

# %% [markdown]
# #### sub
#
# The sub is a function that finds patterns in the target string and substitute them with another string.
#
# flags=re.I --> non-case-sensitive
#
# count = specify number of matches you want to replace

# %%
import re

re.sub?
# Out:
# Signature: re.sub(pattern, repl, string, count=0, flags=0)
# Docstring:
# Return the string obtained by replacing the leftmost
# non-overlapping occurrences of the pattern in string by the
# replacement repl.  repl can be either a string or a callable;
# if a string, backslash escapes in it are processed.  If it is
# a callable, it's passed the Match object and must return
# a replacement string to be used.
# File:      c:\users\shaha\appdata\local\python\pythoncore-3.14-64\lib\re\__init__.py
# Type:      function

# %%
import re

text = 'I am enjoying the Math course.'

print(re.sub(r"Math", "NLP", text, count=1, flags=re.I)) #flags=re.I >> Ignore the case (no matter if M or m)
                                                 # count = 1 >> number of word I need it to change. count= 0 by default
# Out:
# I am enjoying the NLP course.

# %% [markdown]
# __________________________________________________________________________

# %% [markdown]
# ## Text pre-processing steps

# %% [markdown]
# Text preprocessing involves transforming text into a clean and consistent format that can then be fed into a model for further analysis and learning. Raw text data might contain unwanted or unimportant text due to which our results might not give efficient accuracy, and might make it hard to understand and analyze.

# %% [markdown]
# **The various text preprocessing steps are:**
#
# 1. Tokenization.
# 2. Lower casing.
# 3. Stop words removal.
# 4. Stemming.
# 5. Lemmatization.
#
# Before implementing the pre-processing, let us understand the concept first.

# %% [markdown]
# ### Tokenization
#
# Tokenization is used in NLP to split paragraphs and sentences into smaller units that can be more easily assigned meaning.
#
# The first step of the NLP process is gathering the data (a sentence) and breaking it into understandable parts (words).

# %% [markdown]
# - **Sentence Tokenization**

# %%
# %pip install nltk
import nltk
nltk.download('punkt') #Punkt is a pretrained unsupervised machine learning tokenizer model
# Out:
# Requirement already satisfied: nltk in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (8.5.0)
# Requirement already satisfied: joblib in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (4.70.0)
# Requirement already satisfied: colorama in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from tqdm->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shaha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk

text = "I'm enjoying the NLP course! I am also learning new concepts."

nltk.download('punkt_tab')
print(nltk.sent_tokenize(text))
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shaha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ["I'm enjoying the NLP course!", 'I am also learning new concepts.']

# %% [markdown]
# - **Word Tokenzitaion**

# %%
import nltk

text = "I'm enjoying the NLP course!"

print(nltk.word_tokenize(text)) #I'm is tokenized to two tokens [I,m], course! is also tokenized to two tokens [course,!]
# Out:
# ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']

# %%
text = "I'm enjoying the NLP course!"
text.split()
# Out:
# ["I'm", 'enjoying', 'the', 'NLP', 'course!']

# %% [markdown]
# ### Lower Casting

# %% [markdown]
# Converting a word to lower case (NLP -> nlp). Words like Book and book mean the same but when not converted to the lower case those two are represented as two different words in the vector space model (resulting in more dimensions).

# %%
text = "I'm enjoying the NLP course!"
text = text.lower()
print(text)
# Out:
# i'm enjoying the nlp course!

# %% [markdown]
# ### Stemming

# %% [markdown]
# Stemming is basically removing the suffix from a word and reduce it to its root word. For example: “Flying” is a word and its suffix is “ing”, if we remove “ing” from “Flying” then we will get base word or root word which is “Fly”. We uses these suffix to create a new word from original stem word.

# %% [markdown]
# https://www.nltk.org/howto/stem.html

# %% [markdown]
# #### What is PorterStemmer?
#
# It is one of the most popular stemming methods proposed in 1980. It is based on the idea that the suffixes in the English language are made up of a combination of smaller and simpler suffixes. This stemmer is known for its speed and simplicity. The main applications of Porter Stemmer include data mining and Information retrieval. However, its applications are only limited to English words. Also, the group of stems is mapped on to the same stem and the output stem is not necessarily a meaningful word. The algorithms are fairly lengthy in nature and are known to be the oldest stemmer.
#
# > Advantage: It produces the best output as compared to other stemmers and it has less error rate.
#
# > Limitation:  Morphological variants produced are not always real words.

# %%
import nltk
from nltk.stem import PorterStemmer

ps = PorterStemmer() # create a PorterStemmer object

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word + ' --> ' + ps.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fairli

# %% [markdown]
# #### What is SnowballStemmer?
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.
#
# > Advantage: It is slightly faster computation time than porter, with a reasonably large community around it.

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

sn = SnowballStemmer(language='english')

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word+' --> '+sn.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fair

# %% [markdown]
# #### Comparing between porter and snowball

# %%
words = ['generous','generation','generously','generate']

for word in words:
    print(word+' --> '+ps.stem(word))
    print(word+' --> '+sn.stem(word))
    print('---------------------------------------')
# Out:
# generous --> gener
# generous --> generous
# ---------------------------------------
# generation --> gener
# generation --> generat
# ---------------------------------------
# generously --> gener
# generously --> generous
# ---------------------------------------
# generate --> gener
# generate --> generat
# ---------------------------------------

# %% [markdown]
# **Note**: Spacy does not provide stemming

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item. Lemmatization is similar to stemming but it brings context to the words. So it links words with similar meanings to one word.
#
# > One major difference with stemming is that lemmatize takes a part of speech parameter (pos) If not supplied, the default is “noun.”

# %% [markdown]
# | Part of Speech          | Description                | Example Words           |
# | ----------------------- | -------------------------- | ----------------------- |
# | **Noun (N)**            | Person, place, thing, idea | dog, city, love, Python |
# | **Verb (V)**            | Action or state            | run, eat, is, was, jump |
# | **Adjective (ADJ)**     | Describes a noun           | happy, blue, fast       |
# | **Adverb (ADV)**        | Describes a verb/adjective | quickly, very, well     |
# | **Pronoun (PRON)**      | Replaces a noun            | he, she, it, they       |
# | **Preposition (ADP)**   | Shows relationship         | in, on, under, with     |
# | **Conjunction (CONJ)**  | Connects words/clauses     | and, but, or            |
# | **Determiner (DET)**    | Introduces a noun          | a, an, the              |
# | **Interjection (INTJ)** | Expresses emotion          | wow, oh, hey            |

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shaha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.stem import WordNetLemmatizer

text = 'I am enjoying AI courses. I am taking NLP course.'
lemmatizer = WordNetLemmatizer()

for word in nltk.word_tokenize(text):
    print(f"{word}: ", lemmatizer.lemmatize(word))
# Out:
# I:  I
# am:  am
# enjoying:  enjoying
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .

# %%
# Changing pos to verb
for word in nltk.word_tokenize(text):
    print(f"{word}: ", lemmatizer.lemmatize(word, pos='v'))
# Out:
# I:  I
# am:  be
# enjoying:  enjoy
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  be
# taking:  take
# NLP:  NLP
# course:  course
# .:  .

# %% [markdown]
# You may go through Spacy's lemmatizer: https://spacy.io/api/lemmatizer

# %% [markdown]
# ### Stop Words Removal

# %% [markdown]
# The words which are generally filtered out before processing a natural language are called stop words. These are actually the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc) and does not add much information to the text. Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.

# %% [markdown]
# #### Why do we need to remove stopwords?

# %% [markdown]
# By removing these words, we remove the low-level information from our text in order to give more focus to the important information. In order words, we can say that the removal of such words does not show any negative consequences on the model we train for our task.
#
# - reduces the dataset size
# - reduces the training time

# %% [markdown]
# #### Do we always remove stopwords? **NO!**

# %% [markdown]
# We do not always remove the stop words. The removal of stop words is highly dependent on the task we are performing and the goal we want to achieve. For example, if we are training a model that can perform the sentiment analysis task, we might not remove the stop words.
#
# Movie review: “The movie was not good at all.”
#
# Text after removal of stop words: “movie good”

# %%
# %pip install spacy
import subprocess
subprocess.run(['python', '-m', 'spacy', 'download', 'en_core_web_sm'], check=True)
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: spacy in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.8.16)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (0.27.2)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (8.5.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (4.70.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.13.5)
# Requirement already satisfied: jinja2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (84.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.7.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.14.2)
# Requirement already satisfied: httpcore==1.* in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# CompletedProcess(args=['python', '-m', 'spacy', 'download', 'en_core_web_sm'], returncode=0)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
print(len(nlp.Defaults.stop_words))
# Out:
# {'nevertheless', 'whole', 'becoming', 'doing', 'much', 'otherwise', 'eleven', 'could', 'whereas', 'hereby', 'per', 'anything', 'part', 'enough', 'those', 'whence', 'here', 'just', 'move', 'nine', 'herself', 'around', 'were', 'although', 'besides', 'thereupon', 'he', 'would', 'each', 'forty', 'anyhow', 'both', 'until', 'should', 'four', 'beyond', 'whether', 'where', 'there', 'you', 'yours', 'into', 'her', 'me', 'whereafter', 'fifteen', 'front', 'and', 'nowhere', 'therefore', 'even', '‘re', 'none', 'nor', 'amongst', 'last', '’re', 'everything', 'then', 'we', 'our', 'mostly', 'using', 'make', 'they', 'off', 'my', 'cannot', 'once', 'who', 'them', 'can', 'mine', 'of', 'have', 'along', 'after', 'indeed', 'side', 'sometime', 'some', 'hereupon', 'did', 'though', 'further', 'ours', '’ll', 'will', 'without', 'when', 'somehow', 'afterwards', 'same', 'themselves', 're', 'beforehand', 'am', 'thereby', 'is', 'the', 'hers', '‘ll', 'however', 'often', 'also', 'see', 'was', 'former', 'among', 'whose', '’s', 'his', 'something', 'top', 'wherever', 'may', 'became', 'but', 'eight', 'your', 'done', '‘ve', 'everyone', 'nobody', 'or', 'latterly', 'all', "'ve", 'hence', 'out', 'another', 'made', 'such', 'thereafter', 'rather', 'go', 'in', 'already', 'now', 'back', 'someone', 'him', 'yourself', 'few', 'becomes', 'nothing', 'show', 'sometimes', 'ever', 'across', 'serious', 'every', 'a', 'through', 'elsewhere', '‘d', 'with', 'wherein', 'never', 'onto', 'beside', 'always', 'thence', 'that', 'alone', 'five', 'less', 'be', 'quite', 'hundred', 'yet', 'latter', 'below', 'due', 'are', 'still', 'toward', 'over', 'noone', 'others', '‘m', 'whenever', 'regarding', "'re", 'behind', 'no', 'next', 'himself', 'before', 'against', 'unless', 'together', 'what', 'become', 'neither', 'whom', 'third', "'m", 'does', 'put', 'between', 'while', 'it', 'twenty', '‘s', 'so', 'she', 'if', 'whereupon', '’m', 'seems', 'everywhere', 'bottom', 'from', 'again', 'which', 'get', 'formerly', 'least', 'thus', 'full', 'first', 'i', 'because', 'call', 'only', 'to', 'else', 'except', 'whatever', 'really', 'during', 'name', 'amount', 'these', 'ten', 'too', 'why', 'any', '’ve', 'anywhere', 'own', 'thru', 'upon', '’d', 'either', 'us', 'myself', "n't", 'whereby', 'seemed', 'throughout', 'whither', 'well', 'therein', 'being', 'on', 'been', 'anyone', 'more', "'s", 'not', 'one', 'give', 'empty', 'very', 'two', 'used', 'sixty', 'under', 'perhaps', 'n‘t', 'an', 'had', 'might', 'other', 'almost', 'fifty', 'whoever', 'for', 'how', 'three', 'itself', 'towards', 'several', 'ca', 'keep', 'as', "'d", 'n’t', 'must', 'above', 'please', 'yourselves', 'do', 'its', 'than', 'say', 'herein', 'various', 'hereafter', 'seem', 'many', 'via', 'seeming', 'their', 'about', 'has', 'up', 'most', 'namely', 'moreover', 'somewhere', 'anyway', 'since', "'ll", 'by', 'twelve', 'six', 'ourselves', 'meanwhile', 'within', 'down', 'this', 'take', 'at'}
# 326

# %%
print(nlp.vocab['myself'].is_stop)
print(nlp.vocab['mystery'].is_stop)
# Out:
# True
# False

# %%
print (nlp.vocab['btw'].is_stop) #print False
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

nlp.vocab['btw'].is_stop = True # You must update the is_stop flag for the word you added

print (nlp.vocab['btw'].is_stop)
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

print(nlp.vocab['beyond'].is_stop)
# Out:
# False

# %% [markdown]
# ### Stop words in NLTK

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shaha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
print(len(stop_words))
# Out:
# 198

# %%
print(stop_words)
# Out:
# {'hasn', 'will', 'being', 'on', "we're", 'when', 'been', 'doing', 'aren', 'more', 'that', 'not', "you'll", "it'd", 'same', 'themselves', 're', 'be', "it's", "you've", 'am', 'd', 'is', 'shouldn', 'those', 'the', 'here', 'below', 'couldn', 'just', "shan't", 'are', 'hers', 'ours', "don't", 'herself', "they'll", 'very', 'were', 'was', 'over', "i'll", 'he', 'each', 'under', 'until', 'both', "they've", "we've", 'should', "i've", 'needn', 'an', 'no', 'himself', 'before', 'where', 'had', 'against', 'o', 'what', 'other', 'his', 'mustn', 'there', 'you', "we'd", 'yours', "hasn't", 'whom', 'into', 'but', 'for', 'your', 'don', 'her', "they're", "she's", 'how', 'me', 'itself', 'does', "haven't", "that'll", 'm', "isn't", 'between', 'ain', 'and', 'y', "he'd", 'or', "mightn't", 'while', 'it', 'as', "she'd", 'all', 'above', 'didn', "we'll", 'haven', 'so', 'out', 'she', 'if', 'nor', "wouldn't", 'such', 'then', 'we', 'yourselves', 'do', "you're", 'from', 'again', 'our', 'which', "shouldn't", 'its', 'than', 'having', 'ma', 't', "he'll", 'they', "they'd", 'off', "it'll", 'my', 'doesn', 'won', 'in', 'now', "won't", "couldn't", "hadn't", 'their', 'once', "you'd", "wasn't", 'him', 'about', 'i', 'because', 'has', 'hadn', 'mightn', 'only', "i'm", 'to', 'up', 'most', 'who', 'them', 'yourself', 'few', 'weren', 'during', 'can', "didn't", "he's", 'wouldn', 'of', 've', 'by', 'these', 'have', 'too', 'why', 'any', 'after', "i'd", 'ourselves', 'own', "weren't", 'theirs', "mustn't", 'shan', 'wasn', "needn't", 'isn', 'a', "aren't", "she'll", 'through', 'down', "should've", 'some', 'myself', 'did', 'this', 'at', 'with', 'further', 'll', 's', "doesn't"}

# %% [markdown]
# _________________________________________________________________________________________________________

# %% [markdown]
# # Text pre-processing and Regular Expression Tasks:

# %% [markdown]
# # Task 1:
# To make you understand better about the need of text pre-processing. We will do a small project. In this project, you need to find how many hashtags and the top 10 hashtags used in the dataset.
#
# The dataset is about people tweets about apple company on Twitter. You can find the dataset here:
#
# https://www.kaggle.com/datasets/seriousran/appletwittersentimenttexts

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\shaha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\shaha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Libraries
import pandas as pd
import re

# Data set
df = pd.read_csv("apple-twitter-sentiment-texts.csv")

hashtags = []

# Extracting all the hashtags
for text in df['text']:
    htags = re.findall(r"#\w+", str(text))
    hashtags.extend(htags)

print(hashtags)
# Out:
# ['#Note4', '#aapl', '#apple', '#aapl', '#aapl', '#AAPL', '#iPhone6Plus', '#aapl', '#Apple', '#Skyworks', '#SWKS', '#AAPL', '#BRCM', '#MU', '#QCOM', '#VTI', '#aapl', '#Apple', '#AAPL', '#BeatsElectronics', '#Wireless', '#Apple', '#aapl', '#AAPL', '#iFail', '#AAPL', '#Apple', '#aapl', '#Apple', '#Apple', '#iPhone', '#aapl', '#Apple', '#aapl', '#macos', '#yosemite', '#windows8', '#AAPL', '#AAPL', '#CIO', '#iWatch', '#aapl', '#Apple', '#AAPL', '#AAPL', '#aapl', '#Nasdaq', '#android', '#ios', '#samsung', '#aapl', '#ApplePay', '#apple', '#GoodMore', '#GivingTuesday', '#StonerSports', '#3YearsOf5SOS', '#FlashvsArrow', '#stocks', '#aapl', '#Google', '#IPad', '#aapl', '#Will', '#IPhone6Plus', '#Apple', '#Monday', '#December', '#AAPL', '#GamerGate', '#64megaherts', '#AAPL', '#YosemiteProblems', '#apple', '#AAPL', '#AAPL', '#AAPL', '#Apple', '#Stocks', '#Record', '#News', '#iOS8', '#aapl', '#aapl', '#AAPL', '#AAPL', '#AAPL', '#Long', '#YosemiteProblems', '#AAPL', '#Tech', '#goog', '#aapl', '#fb', '#AAPL', '#PinkScreenOfDeath', '#aapl', '#Mac', '#PC', '#apple', '#AAPL', '#ipad', '#irig', '#ripoff', '#yosemite', '#bugs', '#AAPL', '#ThisIsWhyPeopleGetMurdered', '#aapl', '#Apple', '#aapl', '#AAPL', '#LGBT', '#Gayrights', '#Alabama', '#Apple', '#AAPL', '#Apple', '#AAPL', '#Apple', '#AAPL', '#WWDC', '#AppleCordFire', '#SteveJobs', '#apple', '#aapl', '#tech30', '#TL_Chat', '#apple', '#AAPL', '#GoPro', '#Apple', '#gpro', '#aapl', '#mp15', '#iPhone6', '#aapl', '#Howto', '#Apple', '#AAPL', '#JimmyIovine', '#AAPL', '#aapl', '#AppleSnob', '#Apple', '#Google', '#Alibaba', '#baba', '#goog', '#aapl', '#ComputerHistory', '#BethesdaRow', '#AAPL', '#blunderblock', '#Fashion', '#shame', '#fail', '#icloud', '#sucking', '#Apple', '#aapl', '#AAPL', '#AAPL', '#aapl', '#aapl', '#brokenchargerprobs', '#Verr', '#Ger', '#iPhone6s', '#Apple', '#Tuesday', '#December', '#AAPL', '#aapl', '#Stockaction', '#trading', '#Stocks', '#MKt', '#AAPL', '#GOOG', '#GOOGL', '#TSLA', '#WMT', '#PreMarket', '#Markets', '#FTDaily', '#FashionTech', '#applenews', '#iwatch', '#gadgets', '#aapl', '#apple', '#deletegame', '#DieIn', '#livingthedream', '#aapl', '#IOS', '#iPhone', '#AAPL', '#Apple', '#Patents', '#iPhone', '#Tuesday', '#December', '#Trading', '#stocks', '#futures', '#forex', '#trader', '#es', '#aapl', '#gpro', '#eSignal', '#aapl', '#Holiday', '#Giveaway', '#defective', '#sponsorDeal', '#MiniHeartAttack', '#iPhone', '#5starservice', '#BostonHoliday', '#UrbanNutcracker', '#krumpers', '#iPhone', '#shame', '#CreditCare', '#WhatYearIsIt', '#poorcustomerservice', '#aapl', '#parable', '#AppStore', '#Mac', '#PC', '#apple', '#AAPL', '#iOS', '#1', '#infiniteflight', '#aapl', '#AAPL', '#Holiday', '#Giveaway', '#Apple', '#AAPL', '#Tokyo', '#brooklyn', '#Wozniak', '#Jobs', '#Apple', '#aapl', '#disgusting', '#Sydney', '#aapl', '#aapl', '#HourOfCode', '#mkt', '#AAPL', '#PutCallRatios', '#applestorecoventgarden', '#aapl', '#AAPL', '#SupplyChain', '#Operations', '#Apple', '#Facebook', '#fb', '#aapl', '#Wozniak', '#SteveJobs', '#aapl', '#iPod', '#MusicBiz', '#MusicIndustry', '#Apple', '#NYC', '#EricGarner', '#BlackLivesMatters', '#ShutItDown', '#AAPL', '#Winnipeg', '#Apple', '#aapl', '#aapl', '#Swift', '#XCode', '#JustSayin', '#iTunes', '#Yosemite', '#Mavericks', '#tech', '#dontask', '#internet', '#DIY', '#airmilesshops', '#Verizon', '#FIOS', '#Yosemite', '#YosemiteProblems', '#Russia', '#SteveJobs', '#tribute', '#statue', '#Apple', '#AAPL', '#iPhone', '#memorial', '#bastards', '#OnlineFootprint', '#ModicumOfPrudence', '#AppleCordFire', '#Apple', '#aapl', '#badservice', '#Apple', '#AppleSantaMonica', '#Winter', '#Winnipeg', '#AAPL', '#aapl', '#aapl', '#iPhone6', '#Apple', '#aapl', '#iPhone', '#AAPL', '#iTunes', '#antitrust', '#Yosemite', '#sad', '#New', '#Apple', '#iPhone', '#one', '#Sunday', '#December', '#AAPL', '#aapl', '#iPhone6', '#Apple', '#Thursday', '#December', '#aapl', '#vod', '#streaming', '#AppleTV', '#aapl', '#AAPL', '#aapl', '#education', '#Apple', '#Loop', '#iPhone6S', '#Steve',  ...

# %%
# How many Hashtags
print(len(hashtags))
# Out:
# 1616

# %%
hashtagCounts = {}

# Counter for hashtags
for tag in hashtags:
    if tag in hashtagCounts:
        hashtagCounts[tag] += 1
    else:
        hashtagCounts[tag] = 1

# %%
# Extracting #10 Hashtags
sortedHashtags = sorted(hashtagCounts.items(), key=lambda x: x[1], reverse=True)

# Top 10 Hashtags
print(sortedHashtags[:10])
# Out:
# [('#AAPL', 203), ('#aapl', 197), ('#Apple', 134), ('#December', 37), ('#iPhone', 33), ('#apple', 27), ('#iPhone6', 24), ('#Monday', 9), ('#SteveJobs', 9), ('#trading', 9)]

# %% [markdown]
# # Task 2: Using re.compile()
# Given the following text: "This year is 2021"
#
# Write a Python program that:
#
# 1. Use re.compile() to create a regular expression pattern that matches one or more digits.
# 2. Print the type of the compiled pattern.
# 3. Use the compiled pattern to replace 2021 with 2022.
# 4. Print the updated text.
# 5. Briefly explain what re.compile() does and why it is useful when working with regular expressions.

# %%
re.compile?
# Out:
# Signature: re.compile(pattern, flags=0)
# Docstring: Compile a regular expression pattern, returning a Pattern object.
# File:      c:\users\shaha\appdata\local\python\pythoncore-3.14-64\lib\re\__init__.py
# Type:      function

# %%
text = 'This year is 2021'
# 1) 1 or more digits
digits= re.compile(r'\d+')
# 2) print the type
print(type(digits)) 
# 3) replace 2021 with 2022
newText= digits.sub('2022', text,)
# 4) print the updated text
print(newText)
# Out:
# <class 're.Pattern'>
# This year is 2022

# %% [markdown]
# **5) Explain** --> re.copile() is like a user defind function, but here it works with regular expressions. It enables you make a reusable expressions[patterns] so you can repeat using it. It is useful in making your code faster and cleaner.

# %% [markdown]
# # Task 3: Using re.split()
# Given the following text = "a 11 b 2 3 c 4"
#
# Write a Python program that:
#
# 1. Use re.split() with a regular expression pattern to split the text whenever one or more digits appear.
# 2. Print the resulting list.
# 3. Briefly explain: what re.split() does.

# %%
text = "a 11 b 2 3 c 4"
# 1. Use re.split()
list= re.split(r'\d+',text)
# 2. print
print(list)
# Out:
# ['a ', ' b ', ' ', ' c ', '']

# %% [markdown]
# **3. Explain** --> re.split() enables you to split the text when it has something that you dont want to have. It is usefull when you do not want any urls.

# %% [markdown]
# # Task 4: Tokenization Using spaCy
#
# Processes the following sentence: "I'm enjoying the NLP course!"
#
# Write a Python program that:
#
# 1. Use spaCy library and load the small English model en_core_web_sm.
# 2. Iterate through the text and print each token on a separate line.
# 3. Briefly explain: What spacy.load() does.
# 5. Tokenize the same text using nltk library and notice the differences compared to spaCy output.

# %%
# 1.
import spacy
nlp = spacy.load("en_core_web_sm")

sentence= "I'm enjoying the NLP course!"

text= nlp(sentence)

#2.
print("spaCy Tokens:")
for token in text:
    print(token.text)
# Out:
# spaCy Tokens:
# I
# 'm
# enjoying
# the
# NLP
# course
# !

# %% [markdown]
# **3.** --> spacy.load() loads a language model that contains syntax, vocabulary, and processing methods.

# %%
# 4.
import nltk
from nltk.tokenize import word_tokenize

# Tokenize using NLTK
print("\nNLTK Tokens:")
nltkTokens = word_tokenize(sentence)
for token in nltkTokens:
    print(token)
# Out:
# NLTK Tokens:
# I
# 'm
# enjoying
# the
# NLP
# course
# !

# %% [markdown]
# As we notice here, there is no noticeable difference between nltk and spacy. Even so, spacy enables you to load the desired model. And this model is supposed to deal with contractions and ect.

# %%
# Example to see the difference

text = "Wow!! I can't believe it... Visit https://example.com ASAP :)"
doc = nlp(text)

print("spaCy Tokens:")
for token in doc:
    print(token.text)

print("\nNLTK Tokens:")
tokens = word_tokenize(text)
for t in tokens:
    print(t)
# Out:
# spaCy Tokens:
# Wow
# !
# !
# I
# ca
# n't
# believe
# it
# ...
# Visit
# https://example.com
# ASAP
# :)
#
# NLTK Tokens:
# Wow
# !
# !
# I
# ca
# n't
# believe
# it
# ...
# Visit
# https
# :
# //example.com
# ASAP
# :
# )

# %% [markdown]
# **As we can see here, nltk could not process the url!**
